# %% [markdown]
# <a href="https://colab.research.google.com/github/JMagana1903/CSCI-167/blob/main/UDL_8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-up28mq7e
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-up28mq7e
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=8dc6f51ff158d6ac0f3774c34dd950e4828c7b2804d920b16ca6835d663390da
#   Stored in directory: /tmp/pip-ephem-wheel-cache-glwla0bb/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# - I believe that the training error will become zero at around 70 hidden units.
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# - I belive that the first minima of the double descent curve will appear at around 10 hidden units.
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
# - I believe that the maximum of the double descent curve will appear at around 70 hidden units, similar to when training error becomes zero.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.268537, train error 87.78,  test loss 2.264998, test error 87.05
# Epoch   100, train loss 1.858837, train error 70.05,  test loss 1.701933, test error 68.82
# Epoch   200, train loss 1.855564, train error 70.40,  test loss 1.707582, test error 67.90
# Epoch   300, train loss 1.851633, train error 70.05,  test loss 1.701731, test error 68.62
# Epoch   400, train loss 1.852486, train error 69.57,  test loss 1.703113, test error 67.97
# Epoch   500, train loss 1.849609, train error 69.68,  test loss 1.702661, test error 67.78
# Epoch   600, train loss 1.849578, train error 69.90,  test loss 1.697801, test error 68.28
# Epoch   700, train loss 1.850124, train error 70.05,  test loss 1.708846, test error 67.78
# Epoch   800, train loss 1.846657, train error 70.15,  test loss 1.707315, test error 67.68
# Epoch   900, train loss 1.851701, train error 70.80,  test loss 1.718764, test error 67.53
# Training model with   4 hidden variables
# Epoch     0, train loss 2.299058, train error 89.05,  test loss 2.302765, test error 89.28
# Epoch   100, train loss 1.811855, train error 67.35,  test loss 1.651381, test error 64.30
# Epoch   200, train loss 1.798222, train error 66.28,  test loss 1.640797, test error 63.75
# Epoch   300, train loss 1.790790, train error 65.88,  test loss 1.619298, test error 64.22
# Epoch   400, train loss 1.787479, train error 65.70,  test loss 1.623985, test error 63.20
# Epoch   500, train loss 1.780681, train error 65.45,  test loss 1.627921, test error 63.88
# Epoch   600, train loss 1.781787, train error 66.03,  test loss 1.613693, test error 64.38
# Epoch   700, train loss 1.781334, train error 65.07,  test loss 1.630223, test error 63.45
# Epoch   800, train loss 1.784592, train error 66.85,  test loss 1.632482, test error 64.72
# Epoch   900, train loss 1.775341, train error 65.57,  test loss 1.625897, test error 63.85
# Training model with   6 hidden variables
# Epoch     0, train loss 2.303099, train error 89.65,  test loss 2.301078, test error 89.78
# Epoch   100, train loss 1.625839, train error 56.53,  test loss 1.435848, test error 54.83
# Epoch   200, train loss 1.602101, train error 56.22,  test loss 1.422764, test error 54.78
# Epoch   300, train loss 1.591682, train error 56.03,  test loss 1.427189, test error 54.45
# Epoch   400, train loss 1.592821, train error 56.60,  test loss 1.428458, test error 54.90
# Epoch   500, train loss 1.584150, train error 55.55,  test loss 1.413879, test error 54.35
# Epoch   600, train loss 1.582259, train error 55.65,  test loss 1.431299, test error 54.95
# Epoch   700, train loss 1.586513, train error 56.58,  test loss 1.437198, test error 54.17
# Epoch   800, train loss 1.579229, train error 55.92,  test loss 1.428954, test error 55.08
# Epoch   900, train loss 1.579753, train error 56.08,  test loss 1.440326, test error 55.38
# Training model with   8 hidden variables
# Epoch     0, train loss 2.305274, train error 87.88,  test loss 2.305111, test error 87.97
# Epoch   100, train loss 1.509940, train error 51.92,  test loss 1.298790, test error 47.83
# Epoch   200, train loss 1.468511, train error 49.62,  test loss 1.259347, test error 46.72
# Epoch   300, train loss 1.458245, train error 49.33,  test loss 1.270573, test error 46.53
# Epoch   400, train loss 1.441907, train error 48.60,  test loss 1.246163, test error 46.70
# Epoch   500, train loss 1.427577, train error 49.12,  test loss 1.260379, test error 47.12
# Epoch   600, train loss 1.426667, train error 48.25,  test loss 1.262969, test error 46.95
# Epoch   700, train loss 1.425468, train error 48.58,  test loss 1.277609, test error 47.30
# Epoch   800, train loss 1.423654, train error 47.95,  test loss 1.264749, test error 46.55
# Epoch   900, train loss 1.421074, train error 48.15,  test loss 1.281620, test error 47.00
# Training model with  10 hidden variables
# Epoch     0, train loss 2.184718, train error 81.68,  test loss 2.131410, test error 79.85
# Epoch   100, train loss 1.590626, train error 55.65,  test loss 1.452739, test error 56.12
# Epoch   200, train loss 1.556575, train error 54.42,  test loss 1.459815, test error 56.38
# Epoch   300, train loss 1.537283, train error 53.85,  test loss 1.477664, test error 56.70
# Epoch   400, train loss 1.528783, train error 54.00,  test loss 1.496024, test error 56.72
# Epoch   500, train loss 1.520438, train error 53.65,  test loss 1.500725, test error 57.03
# Epoch   600, train loss 1.521542, train error 53.88,  test loss 1.524831, test error 57.28
# Epoch   700, train loss 1.518232, train error 53.08,  test loss 1.539490, test error 57.53
# Epoch   800, train loss 1.507880, train error 53.03,  test loss 1.519010, test error 56.12
# Epoch   900, train loss 1.503569, train error 53.00,  test loss 1.525986, test error 56.53
# Training model with  14 hidden variables
# Epoch     0, train loss 2.227485, train error 82.12,  test loss 2.214609, test error 82.18
# Epoch   100, train loss 1.405798, train error 48.15,  test loss 1.304836, test error 47.90
# Epoch   200, train loss 1.318540, train error 43.55,  test loss 1.289047, test error 47.35
# Epoch   300, train loss 1.287222, train error 43.10,  test loss 1.303773, test error 46.62
# Epoch   400, train loss 1.276573, train error 43.10,  test loss 1.332440, test error 48.25
# Epoch   500, train loss 1.257618, train error 42.17,  test loss 1.326184, test error 46.97
# Epoch   600, train loss 1.253054, train error 42.58,  test loss 1.331898, test error 47.80
# Epoch   700, train loss 1.253182, train error 42.00,  test loss 1.345768, test error 47.67
# Epoch   800, train loss 1.253729, train error 42.40,  test loss 1.359654, test error 48.10
# Epoch   900, train loss 1.247978, train error 42.28,  test loss 1.361911, test error 47.92
# Training model with  18 hidden variables
# Epoch     0, train loss 2.147989, train error 81.57,  test loss 2.116764, test error 80.43
# Epoch   100, train loss 1.334205, train error 44.65,  test loss 1.324692, test error 50.45
# Epoch   200, train loss 1.243283, train error 42.08,  test loss 1.370787, test error 50.95
# Epoch   300, train loss 1.206322, train error 40.47,  test loss 1.407503, test error 51.83
# Epoch   400, train loss 1.194536, train error 40.40,  test loss 1.439666, test error 51.88
# Epoch   500, train loss 1.172192, train error 40.20,  test loss 1.461201, test error 52.03
# Epoch   600, train loss 1.162370, train error 39.47,  test loss 1.480280, test error 52.08
# Epoch   700, train loss 1.159485, train error 39.60,  test loss 1.494671, test error 52.75
# Epoch   800, train loss 1.150454, train error 39.08,  test loss 1.514376, test error 52.67
# Epoch   900, train loss 1.156380, train error 39.72,  test loss 1.548158, test error 53.33
# Training model with  22 hidden variables
# Epoch     0, train loss 2.224853, train error 82.68,  test loss 2.212959, test error 81.82
# Epoch   100, train loss 1.319374, train error 43.92,  test loss 1.388956, test error 52.30
# Epoch   200, train loss 1.175130, train error 39.97,  test loss 1.434430, test error 52.50
# Epoch   300, train loss 1.109533, train error 37.17,  test loss 1.486274, test error 52.15
# Epoch   400, train loss 1.082412, train error 36.62,  test loss 1.540607, test error 52.62
# Epoch   500, train loss 1.043192, train error 35.38,  test loss 1.586778, test error 53.03
# Epoch   600, train loss 1.038222, train error 35.05,  test loss 1.656763, test error 53.45
# Epoch   700, train loss 1.018405, train error 34.60,  test loss 1.681380, test error 54.05
# Epoch   800, train loss 1.001628, train error 34.30,  test loss 1.711863, test error 53.58
# Epoch   900, train loss 0.989799, train error 34.55,  test loss 1.753153, test error 54.38
# Training model with  26 hidden variables
# Epoch     0, train loss 2.139673, train error 79.00,  test loss 2.097198, test error 78.03
# Epoch   100, train loss 1.239082, train error 41.95,  test loss 1.369339, test error 50.30
# Epoch   200, train loss 1.070982, train error 36.70,  test loss 1.454651, test error 50.67
# Epoch   300, train loss 0.995103, train error 34.32,  test loss 1.559684, test error 51.53
# Epoch   400, train loss 0.957043, train error 33.10,  test loss 1.656463, test error 52.50
# Epoch   500, train loss 0.909383, train error 30.95,  test loss 1.706371, test error 52.05
# Epoch   600, train loss 0.890915, train error 29.82,  test loss 1.783366, test error 52.22
# Epoch   700, train loss 0.870276, train error 29.53,  test loss 1.875207, test error 53.97
# Epoch   800, train loss 0.868722, train error 30.25,  test loss 1.885932, test error 53.17
# Epoch   900, train loss 0.849157, train error 29.32,  test loss 1.952384, test error 54.42
# Training model with  30 hidden variables
# Epoch     0, train loss 2.168057, train error 79.07,  test loss 2.144927, test error 80.68
# Epoch   100, train loss 1.104196, train error 36.30,  test loss 1.369984, test error 48.83
# Epoch   200, train loss 0.909235, train error 29.40,  test loss 1.534046, test error 49.47
# Epoch   300, train loss 0.815151, train error 27.80,  test loss 1.744291, test error 51.40
# Epoch   400, train loss 0.765077, train error 25.47,  test loss 1.932260, test error 51.55
# Epoch   500, train loss 0.731159, train error 24.70,  test loss 2.092185, test error 53.45
# Epoch   600, train loss 0.705657, train error 23.80,  test loss 2.300678, test error 54.35
# Epoch   700, train loss 0.679138, train error 23.35,  test loss 2.406054, test error 54.33
# Epoch   800, train loss 0.657983, train error 22.05,  test loss 2.533790, test error 55.17
# Epoch   900, train loss 0.641750, train error 22.12,  test loss 2.660950, test error 54.88
# Training model with  35 hidden variables
# Epoch     0, train loss 2.145849, train error 78.35,  test loss 2.108031, test error 77.60
# Epoch   100, train loss 1.027565, train error 33.38,  test loss 1.399861, test error 50.50
# Epoch   200, train loss 0.816796, train error 27.72,  test loss 1.714978, test error 52.12
# Epoch   300, train loss 0.693927, train error 23.82,  test loss 2.031688, test error 52.85
# Epoch   400, train loss 0.616253, train error 20.28,  test loss 2.401746, test error 54.30
# Epoch   500, train loss 0.572919, train error 19.47,  test loss 2.742029, test error 55.30
# Epoch   600, train loss 0.523916, train error 17.93,  test loss 3.007217, test error 54.85
# Epoch   700, train loss 0.496162, train error 16.35,  test loss 3.288976, test error 55.42
# Epoch   800, train loss 0.504838, train error 17.97,  test loss 3.648326, test error 56.55
# Epoch   900, train loss 0.468309, train error 15.70,  test loss 3.869284, test error 56.15
# Training model with  40 hidden variables
# Epoch     0, train loss 2.077509, train error 76.55,  test loss 2.031336, test error 77.15
# Epoch   100, train loss 0.934718, train error 29.75,  test loss 1.413854, test error 49.50
# Epoch   200, train loss 0.637436, train error 20.82,  test loss 1.884749, test error 52.40
# Epoch   300, train loss 0.509189, train error 17.25,  test loss 2.556107, test error 55.22
# Epoch   400, train loss 0.411260, train error 14.12,  test loss 3.327594, test error 55.15
# Epoch   500, train loss 0.321558, train error 10.80,  test loss 3.984373, test error 55.92
# Epoch   600, train loss 0.290068, train error 10.38,  test loss 4.737884, test error 56.83
# Epoch   700, train loss 0.294574, train error 10.57,  test loss 5.479151, test error 56.88
# Epoch   800, train loss 0.293269, train error 10.50,  test loss 6.058403, test error 56.47
# Epoch   900, train loss 0.250115, train error 9.35,  test loss 6.747938, test error 57.28
# Training model with  45 hidden variables
# Epoch     0, train loss 2.125838, train error 79.65,  test loss 2.095193, test error 79.65
# Epoch   100, train loss 0.832547, train error 27.03,  test loss 1.514939, test error 50.75
# Epoch   200, train loss 0.502042, train error 15.78,  test loss 2.198487, test error 53.08
# Epoch   300, train loss 0.318451, train error 9.75,  test loss 3.151303, test error 54.88
# Epoch   400, train loss 0.232819, train error 6.93,  test loss 4.349539, test error 56.50
# Epoch   500, train loss 0.221748, train error 7.53,  test loss 5.634899, test error 56.83
# Epoch   600, train loss 0.238206, train error 8.40,  test loss 6.984541, test error 58.65
# Epoch   700, train loss 0.226272, train error 7.93,  test loss 7.868571, test error 56.40
# Epoch   800, train loss 0.214034, train error 6.88,  test loss 8.728663, test error 57.30
# Epoch   900, train loss 0.006052, train error 0.00,  test loss 9.467877, test error 57.55
# Training model with  50 hidden variables
# Epoch     0, train loss 2.153723, train error 79.88,  test loss 2.147777, test error 80.30
# Epoch   100, train loss 0.746650, train error 23.10,  test loss 1.621624, test error 50.80
# Epoch   200, train loss 0.345524, train error 10.50,  test loss 2.718015, test error 55.12
# Epoch   300, train loss 0.141778, train error 3.10,  test loss 4.400269, test error 57.28
# Epoch   400, train loss 0.030337, train error 0.03,  test loss 6.104616, test error 57.70
# Epoch   500, train loss 0.013962, train error 0.00,  test loss 7.096956, test error 57.47
# Epoch   600, train loss 0.008636, train error 0.00,  test loss 7.769988, test error 57.75
# Epoch   700, train loss 0.006176, train error 0.00,  test loss 8.278154, test error 57.72
# Epoch   800, train loss 0.004788, train error 0.00,  test loss 8.695629, test error 57.65
# Epoch   900, train loss 0.003855, train error 0.00,  test loss 9.038936, test error 57.80
# Training model with  55 hidden variables
# Epoch     0, train loss 2.111874, train error 78.15,  test loss 2.091043, test error 77.25
# Epoch   100, train loss 0.598547, train error 18.82,  test loss 1.735031, test error 52.12
# Epoch   200, train loss 0.205674, train error 4.90,  test loss 3.087033, test error 53.50
# Epoch   300, train loss 0.036947, train error 0.03,  test loss 4.823140, test error 55.72
# Epoch   400, train loss 0.013333, train error 0.00,  test loss 5.805177, test error 56.10
# Epoch   500, train loss 0.007812, train error 0.00,  test loss 6.412495, test error 56.05
# Epoch   600, train loss 0.005405, train error 0.00,  test loss 6.843096, test error 56.12
# Epoch   700, train loss 0.004082, train error 0.00,  test loss 7.180738, test error 56.10
# Epoch   800, train loss 0.003249, train error 0.00,  test loss 7.458024, test error 56.22
# Epoch   900, train loss 0.002669, train error 0.00,  test loss 7.698571, test error 56.20
# Training model with  60 hidden variables
# Epoch     0, train loss 2.077951, train error 77.00,  test loss 2.029348, test error 77.12
# Epoch   100, train loss 0.546525, train error 16.43,  test loss 1.771139, test error 52.30
# Epoch   200, train loss 0.097819, train error 0.75,  test loss 3.458177, test error 54.03
# Epoch   300, train loss 0.018280, train error 0.00,  test loss 4.762094, test error 55.05
# Epoch   400, train loss 0.008977, train error 0.00,  test loss 5.426437, test error 55.15
# Epoch   500, train loss 0.005786, train error 0.00,  test loss 5.869484, test error 55.22
# Epoch   600, train loss 0.004148, train error 0.00,  test loss 6.200890, test error 55.45
# Epoch   700, train loss 0.003174, train error 0.00,  test loss 6.454101, test error 55.33
# Epoch   800, train loss 0.002561, train error 0.00,  test loss 6.671374, test error 55.42
# Epoch   900, train loss 0.002129, train error 0.00,  test loss 6.854854, test error 55.53
# Training model with  70 hidden variables
# Epoch     0, train loss 2.023843, train error 76.00,  test loss 1.977712, test error 77.95
# Epoch   100, train loss 0.366401, train error 9.12,  test loss 1.948821, test error 53.42
# Epoch   200, train loss 0.034767, train error 0.03,  test loss 3.532488, test error 54.25
# Epoch   300, train loss 0.011523, train error 0.00,  test loss 4.298324, test error 53.85
# Epoch   400, train loss 0.006284, train error 0.00,  test loss 4.740928, test error 54.17
# Epoch   500, train loss 0.004225, train error 0.00,  test loss 5.045762, test error 54.28
# Epoch   600, train loss 0.003125, train error 0.00,  test loss 5.276348, test error 54.20
# Epoch   700, train loss 0.002458, train error 0.00,  test loss 5.466621, test error 54.22
# Epoch   800, train loss 0.002007, train error 0.00,  test loss 5.624008, test error 54.25
# Epoch   900, train loss 0.001689, train error 0.00,  test loss 5.760132, test error 54.17
# Training model with  80 hidden variables
# Epoch     0, train loss 2.003126, train error 74.10,  test loss 1.966830, test error 74.90
# Epoch   100, train loss 0.244060, train error 4.70,  test loss 2.023059, test error 51.97
# Epoch   200, train loss 0.021532, train error 0.00,  test loss 3.351560, test error 52.92
# Epoch   300, train loss 0.008287, train error 0.00,  test loss 3.909691, test error 53.22
# Epoch   400, train loss 0.004914, train error 0.00,  test loss 4.236093, test error 53.25
# Epoch   500, train loss 0.003400, train error 0.00,  test loss 4.472634, test error 53.22
# Epoch   600, train loss 0.002557, train error 0.00,  test loss 4.657608, test error 53.15
# Epoch   700, train loss 0.002028, train error 0.00,  test loss 4.807868, test error 53.08
# Epoch   800, train loss 0.001670, train error 0.00,  test loss 4.934366, test error 53.00
# Epoch   900, train loss 0.001411, train error 0.00,  test loss 5.045106, test error 52.97
# Training model with  90 hidden variables
# Epoch     0, train loss 1.998557, train error 74.18,  test loss 1.943426, test error 74.28
# Epoch   100, train loss 0.144232, train error 1.43,  test loss 2.125516, test error 51.55
# Epoch   200, train loss 0.015019, train error 0.00,  test loss 3.162187, test error 52.25
# Epoch   300, train loss 0.006661, train error 0.00,  test loss 3.586480, test error 52.28
# Epoch   400, train loss 0.004050, train error 0.00,  test loss 3.849450, test error 52.22
# Epoch   500, train loss 0.002848, train error 0.00,  test loss 4.041076, test error 52.30
# Epoch   600, train loss 0.002164, train error 0.00,  test loss 4.190304, test error 52.33
# Epoch   700, train loss 0.001731, train error 0.00,  test loss 4.311128, test error 52.25
# Epoch   800, train loss 0.001432, train error 0.00,  test loss 4.413193, test error 52.20
# Epoch   900, train loss 0.001216, train error 0.00,  test loss 4.503017, test error 52.22
# Training model with 100 hidden variables
# Epoch     0, train loss 1.994156, train error 74.82,  test loss 1.921299, test error 74.82
# Epoch   100, train loss 0.100413, train error 0.35,  test loss 2.179136, test error 51.33
# Epoch   200, train loss 0.013300, train error 0.00,  test loss 3.090682, test error 51.20
# Epoch   300, train loss 0.006109, train error 0.00,  test loss 3.462416, test error 51.25
# Epoch   400, train loss 0.003766, train error 0.00,  test loss 3.701749, test error 51.12
# Epoch   500, train loss 0.002665, train error 0.00,  test loss 3.870166, test error 51.30
# Epoch   600, train loss 0.002035, train error 0.00,  test loss 4.003247, test error 51.20
# Epoch   700, train loss 0.001631, train error 0.00,  test loss 4.112803, test error 51.15
# Epoch   800, train loss 0.001352, train error 0.00,  test loss 4.206026, test error 51.28
# Epoch   900, train loss 0.001149, train error 0.00,  test loss 4.286402, test error 51.22
# Training model with 120 hidden variables
# Epoch     0, train loss 1.964685, train error 72.43,  test loss 1.890401, test error 72.95
# Epoch   100, train loss 0.047477, train error 0.00,  test loss 2.180753, test error 49.83
# Epoch   200, train loss 0.009230, train error 0.00,  test loss 2.732559, test error 49.70
# Epoch   300, train loss 0.004604, train error 0.00,  test loss 2.997787, test error 49.45
# Epoch   400, train loss 0.002961, train error 0.00,  test loss 3.167613, test error 49.30
# Epoch   500, train loss 0.002144, train error 0.00,  test loss 3.293474, test error 49.38
# Epoch   600, train loss 0.001660, train error 0.00,  test loss 3.393812, test error 49.50
# Epoch   700, train loss 0.001346, train error 0.00,  test loss 3.476110, test error 49.50
# Epoch   800, train loss 0.001125, train error 0.00,  test loss 3.546911, test error 49.53
# Epoch   900, train loss 0.000962, train error 0.00,  test loss 3.607307, test error 49.55
# Training model with 140 hidden variables
# Epoch     0, train loss 1.961666, train error 73.40,  test loss 1.895334, test error 73.45
# Epoch   100, train loss 0.036246, train error 0.00,  test loss 2.183835, test error 49.75
# Epoch   200, train loss 0.008240, train error 0.00,  test loss 2.688899, test error 50.00
# Epoch   300, train loss 0.004228, train error 0.00,  test loss 2.931935, test error 50.10
# Epoch   400, train loss 0.002745, train error 0.00,  test loss 3.087780, test error 50.08
# Epoch   500, train loss 0.001997, train error 0.00,  test loss 3.204065, test error 49.95
# Epoch   600, train loss 0.001551, train error 0.00,  test loss 3.298022, test error 49.95
# Epoch   700, train loss 0.001260, train error 0.00,  test loss 3.374691, test error 50.10
# Epoch   800, train loss 0.001054, train error 0.00,  test loss 3.440794, test error 50.17
# Epoch   900, train loss 0.000903, train error 0.00,  test loss 3.498734, test error 50.15
# Training model with 160 hidden variables
# Epoch     0, train loss 1.941190, train error 71.60,  test loss 1.878235, test error 74.03
# Epoch   100, train loss 0.030289, train error 0.00,  test loss 2.083904, test error 48.50
# Epoch   200, train loss 0.007409, train error 0.00,  test loss 2.497755, test error 48.60
# Epoch   300, train loss 0.003875, train error 0.00,  test loss 2.697096, test error 48.83
# Epoch   400, train loss 0.002540, train error 0.00,  test loss 2.831459, test error 48.83
# Epoch   500, train loss 0.001856, train error 0.00,  test loss 2.928351, test error 48.72
# Epoch   600, train loss 0.001447, train error 0.00,  test loss 3.007452, test error 48.80
# Epoch   700, train loss 0.001178, train error 0.00,  test loss 3.072121, test error 48.83
# Epoch   800, train loss 0.000988, train error 0.00,  test loss 3.129071, test error 48.88
# Epoch   900, train loss 0.000847, train error 0.00,  test loss 3.178242, test error 48.78
# Training model with 180 hidden variables
# Epoch     0, train loss 1.926944, train error 69.95,  test loss 1.834605, test error 71.78
# Epoch   100, train loss 0.025029, train error 0.00,  test loss 1.982257, test error 48.67
# Epoch   200, train loss 0.006692, train error 0.00,  test loss 2.319562, test error 48.88
# Epoch   300, train loss 0.003575, train error 0.00,  test loss 2.486871, test error 48.72
# Epoch   400, train loss 0.002364, train error 0.00,  test loss 2.600028, test error 48.65
# Epoch   500, train loss 0.001737, train error 0.00,  test loss 2.684253, test error 48.67
# Epoch   600, train loss 0.001359, train error 0.00,  test loss 2.752399, test error 48.62
# Epoch   700, train loss 0.001109, train error 0.00,  test loss 2.808920, test error 48.55
# Epoch   800, train loss 0.000933, train error 0.00,  test loss 2.857299, test error 48.55
# Epoch   900, train loss 0.000801, train error 0.00,  test loss 2.899932, test error 48.53
# Training model with 200 hidden variables
# Epoch     0, train loss 1.893694, train error 68.90,  test loss 1.826505, test error 71.60
# Epoch   100, train loss 0.021639, train error 0.00,  test loss 2.071607, test error 49.42
# Epoch   200, train loss 0.006180, train error 0.00,  test loss 2.394462, test error 49.15
# Epoch   300, train loss 0.003351, train error 0.00,  test loss 2.558820, test error 49.17
# Epoch   400, train loss 0.002234, train error 0.00,  test loss 2.667452, test error 49.05
# Epoch   500, train loss 0.001649, train error 0.00,  test loss 2.749712, test error 49.08
# Epoch   600, train loss 0.001295, train error 0.00,  test loss 2.816956, test error 49.08
# Epoch   700, train loss 0.001059, train error 0.00,  test loss 2.872555, test error 49.15
# Epoch   800, train loss 0.000892, train error 0.00,  test loss 2.920410, test error 49.25
# Epoch   900, train loss 0.000767, train error 0.00,  test loss 2.962612, test error 49.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.868481, train error 66.68,  test loss 1.802184, test error 69.93
# Epoch   100, train loss 0.017071, train error 0.00,  test loss 1.890772, test error 46.75
# Epoch   200, train loss 0.005324, train error 0.00,  test loss 2.135355, test error 46.85
# Epoch   300, train loss 0.002965, train error 0.00,  test loss 2.266113, test error 46.67
# Epoch   400, train loss 0.001999, train error 0.00,  test loss 2.356766, test error 46.55
# Epoch   500, train loss 0.001487, train error 0.00,  test loss 2.425358, test error 46.53
# Epoch   600, train loss 0.001173, train error 0.00,  test loss 2.481251, test error 46.58
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.527056, test error 46.58
# Epoch   800, train loss 0.000813, train error 0.00,  test loss 2.566863, test error 46.60
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.601557, test error 46.70
# Training model with 300 hidden variables
# Epoch     0, train loss 1.876184, train error 67.05,  test loss 1.828298, test error 71.28
# Epoch   100, train loss 0.014330, train error 0.00,  test loss 1.864258, test error 46.47
# Epoch   200, train loss 0.004792, train error 0.00,  test loss 2.086659, test error 46.70
# Epoch   300, train loss 0.002719, train error 0.00,  test loss 2.206264, test error 46.62
# Epoch   400, train loss 0.001850, train error 0.00,  test loss 2.287982, test error 46.88
# Epoch   500, train loss 0.001384, train error 0.00,  test loss 2.350738, test error 47.00
# Epoch   600, train loss 0.001097, train error 0.00,  test loss 2.401814, test error 46.97
# Epoch   700, train loss 0.000904, train error 0.00,  test loss 2.443857, test error 47.00
# Epoch   800, train loss 0.000765, train error 0.00,  test loss 2.480544, test error 46.97
# Epoch   900, train loss 0.000661, train error 0.00,  test loss 2.513095, test error 47.00
# Training model with 400 hidden variables
# Epoch     0, train loss 1.815055, train error 64.05,  test loss 1.745559, test error 67.85
# Epoch   100, train loss 0.011710, train error 0.00,  test loss 1.812378, test error 45.95
# Epoch   200, train loss 0.004177, train error 0.00,  test loss 1.999578, test error 45.85
# Epoch   300, train loss 0.002419, train error 0.00,  test loss 2.102300, test error 45.75
# Epoch   400, train loss 0.001666, train error 0.00,  test loss 2.173109, test error 45.60
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.228504, test error 45.45
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.272144, test error 45.47
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.310059, test error 45.45
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.342632, test error 45.35
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.370675, test error 45.40

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
